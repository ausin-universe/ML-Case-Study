# %%
X = car_data.drop('brand',axis=1)
y = car_data['brand']

# %%
graph_data = open('graph.dot','w')
export_graphiz(dt_car, out_filled=True, special_characters=True, feature_names=list(X_train.columns),class_names=list(lb.classes_)

graph_data.close()
