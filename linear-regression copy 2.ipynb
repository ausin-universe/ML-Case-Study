# %% [markdown]
# ## Problem Statement
#
# perform linear regression on datasets named advertisements

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm

# %%
data = pd.read_csv('advertising.csv')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
x = data['TV']
y = data['Sales']

plt.figure()
plt.scatter(x,y)
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
reg = LinearRegression()

# %%
X = data['TV'].values.reshape(-1,1)
y = data['Sales'].values.reshape(-1,1)

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.predict(X)
# Out:
# array([[19.73726517],
#        [ 9.44300377],
#        [ 7.92881554],
#        [15.37773421],
#        [17.00285199],
#        [ 7.45736499],
#        [10.16404579],
#        [13.6416869 ],
#        [ 7.45181851],
#        [18.05668263],
#        [10.64104282],
#        [18.88310771],
#        [ 8.29488303],
#        [12.38263661],
#        [18.29518114],
#        [17.81263764],
#        [10.73533293],
#        [22.5826079 ],
#        [10.8129836 ],
#        [15.14478218],
#        [19.08832736],
#        [20.142158  ],
#        [ 7.70695646],
#        [19.63742859],
#        [10.43027669],
#        [21.55650964],
#        [14.90073719],
#        [20.29191288],
#        [20.77445638],
#        [10.89063428],
#        [23.22045276],
#        [13.23679407],
#        [12.36599718],
#        [21.70626452],
#        [12.28280002],
#        [23.09843026],
#        [21.77836873],
#        [11.11803984],
#        [ 9.3653531 ],
#        [19.62078916],
#        [18.20643751],
#        [16.79208586],
#        [23.2592781 ],
#        [18.4504825 ],
#        [ 8.36698723],
#        [16.6867028 ],
#        [11.9500114 ],
#        [20.28081992],
#        [19.57641734],
#        [10.68541463],
#        [18.05668263],
#        [12.54348444],
#        [18.97739782],
#        [17.10268858],
#        [21.54541669],
#        [18.00676433],
#        [ 7.37971431],
#        [14.52912323],
#        [18.6667951 ],
#        [18.66124863],
#        [ 9.94218671],
#        [21.46776601],
#        [20.24754106],
#        [12.67105342],
#        [14.2462529 ],
#        [10.80189065],
#        [ 8.72196176],
#        [14.70106401],
#        [20.142158  ],
#        [18.99958373],
#        [18.01785729],
#        [13.06485329],
#        [ 8.46127734],
#        [14.15196279],
#        [18.81100351],
#        [ 7.91217611],
#        [ 8.50010268],
#        [13.65832633],
#        [ 7.27433125],
#        [13.40873486],
#        [11.21232995],
#        [20.27527345],
#        [11.1513187 ],
#        [10.76861179],
#        [18.81654998],
#        [17.69061514],
#        [11.20678348],
#        [13.11477158],
#        [11.87236072],
#        [13.06485329],
#        [14.42374016],
#        [ 8.56111392],
#        [19.04950202],
#        [20.8909324 ],
#        [12.93173784],
#        [16.03221851],
#        [17.93466013],
#        [17.23025755],
#        [23.04296549],
#        [14.47365846],
#        [19.31018644],
#        [23.41457946],
#        [22.51605017],
#        [17.39665186],
#        [20.18652981],
#        [14.62341334],
#        [ 8.36144075],
#        [11.98883674],
#        [ 7.70140998],
#        [21.14052387],
#        [19.49876666],
#        [20.38065651],
#        [16.71998166],
#        [18.60023738],
#        [11.31216654],
#        [11.14022575],
#        [14.69551754],
#        [11.21232995],
#        [13.94674314],
#        [ 8.05083804],
#        [14.81199356],
#        [ 8.01755917],
#        [19.39893007],
#        [13.80253473],
#        [19.70398631],
#        [11.81134947],
#        [ 7.4074467 ],
#        [11.42309608],
#        [19.19371042],
#        [10.28052181],
#        [ 7.01364683],
#        [21.68407862],
#        [ 7.44072556],
#        [19.16597804],
#        [ 9.02147152],
#        [ 9.6537699 ],
#        [ 8.39471961],
#        [22.15552917],
#        [ 9.35980662],
#        [17.23025755],
#        [11.04593564],
#        [17.71834753],
#        [19.20480338],
#        [12.77643648],
#        [12.31053241],
#        [14.75652879],
#        [20.29191288],
#        [20.46385367],
#        [ 9.08248277],
#        [ 9.45409673],
#        [22.54378256],
#        [13.68605872],
#        [17.93466013],
#        [16.47593667],
#        [17.39110538],
#        [ 7.20222705],
#        [12.18296344],
#        [15.2834441 ],
#        [ 7.6237593 ],
#        [14.27953176],
#        [16.54249439],
#        [11.72815232],
#        [17.42438424],
#        [16.04331146],
#        [13.47529259],
#        [19.98131016],
#        [ 7.96764088],
#        [18.44493602],
#        [18.92193305],
#        [22.74345573],
#        [ 9.74806001],
#        [16.09877623],
#        [ 8.06193099],
#        [16.31508884],
#        [19.31018644],
#        [22.33301643],
#        [20.75227047],
#        [16.41492542],
#        [22.32192348],
#        [16.15978748],
#        [15.66060454],
#        [19.09387384],
#        [10.09194159],
#        [22.92648948],
#        [21.05178023],
#        [18.34509943],
#        [14.71215697],
#        [17.57413912],
#        [22.83774584],
#        [ 8.0120127 ],
#        [ 9.16567992],
#        [11.16241166],
#        [ 7.92881554],
#        [16.2263452 ],
#        [15.27789763],
#        [ 9.09357572],
#        [12.19960287],
#        [16.79208586],
#        [22.70463039],
#        [19.84819471]])

# %%
r2_score_value = r2_score(y, reg.predict(X))
r2_score_value
# Out:
# 0.8121757029987414

# %%
mse = mean_squared_error(y, reg.predict(X))
mse
# Out:
# 5.2177438977951285

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     856.2
# Date:                Tue, 30 Jul 2024   Prob (F-statistic):           7.93e-74
# Time:                        04:27:58   Log-Likelihood:                -448.99
# No. Observations:                 200   AIC:                             902.0
# Df Residuals:                     198   BIC:                             908.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9748      0.323     21.624      0.000       6.339       7.611
# x1             0.0555      0.002     29.260      0.000       0.052       0.059
# ==============================================================================
# Omnibus:                        0.013   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.993   Jarque-Bera (JB):                0.043
# Skew:                          -0.018   Prob(JB):                        0.979
# Kurtosis:                       2.938   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
